# %% [markdown]
# # Projeto 1 - Análise de Partidas de Futebol Masculino e Feminino
#
# Disciplina: ESTATÍSTICAS APLICADAS À COMPUTAÇÃO
#
# Professor: Paulo Ribeiro
#
# Aluno(s):
# - AïCHA NACAMBO
# - ARTHUR CORDEIRO
#
# Data: 13/06/2026

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
